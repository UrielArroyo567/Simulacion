# %% [markdown]
# <a href="https://colab.research.google.com/github/UrielArroyo567/Simulacion/blob/main/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # simulacion
# ## Unidad 1
# ### Practica 1. Generacion de numeros aleatorios por el metodo de centros al cuadrado
# Maestro: Jose Gabriel
# Alumno: Jose Uriel Arroyo Chavez

# %%
# semilla inicial
semilla = 2005
n = 4
iteraciones = 100
resultados = []

for _ in range(iteraciones):
  #elevar la semilla al cuadrado
  cuadrado = str(semilla ** 2).zfill(2 * n )# agregar los esdpacios necesarios
  # extraer los digitos centrales
  inicio = (len (cuadrado) - n) // 2
  semilla = int (cuadrado[inicio:inicio + n])
  resultados.append(semilla)

  #imprimir resultados
  for i, numero in enumerate(resultados, 1):
    print(f"Numero aleatrorio{i}:{numero}")
# Out:
# Numero aleatrorio1:200
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio3:1600
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio3:1600
# Numero aleatrorio4:5600
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio3:1600
# Numero aleatrorio4:5600
# Numero aleatrorio5:3600
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio3:1600
# Numero aleatrorio4:5600
# Numero aleatrorio5:3600
# Numero aleatrorio6:9600
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio3:1600
# Numero aleatrorio4:5600
# Numero aleatrorio5:3600
# Numero aleatrorio6:9600
# Numero aleatrorio7:1600
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio3:1600
# Numero aleatrorio4:5600
# Numero aleatrorio5:3600
# Numero aleatrorio6:9600
# Numero aleatrorio7:1600
# Numero aleatrorio8:5600
# Numero aleatrorio1:200
# Numero aleatrorio2:400
# Numero aleatrorio3:1600
# ...
