# %% [markdown]
# <a href="https://colab.research.google.com/github/UrielArroyo567/Simulacion/blob/main/NumAleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #simulacion Unidad 1
# ##Practica 1. Generacion de 100 numeros aleatorios por el metodo de centros al cuadrado y por el metodo de medios cuadrados
# ###Maestro: Jose Gabriel
# ###Alumno: Jose Uriel Arroyo Chavez

# %%
# Método de Centros Cuadrados
# Semilla inicial
semilla = 9375
n = 4
iteraciones = 100
resultados = []

for _ in range(iteraciones):
    # Elevar la semilla al cuadrado
    cuadrado = str(semilla ** 2).zfill(2 * n)
    # Extraer los dígitos centrales
    inicio = (len(cuadrado) - n) // 2
    semilla = int(cuadrado[inicio:inicio + n])

    # Evitar 0000 como semilla
    if semilla == 0:
        semilla = 1

    resultados.append(semilla)

# Imprimir resultados
for i, numero in enumerate(resultados, 1):
    print(f"Número aleatorio {i}: {numero}")
# Out:
# Número aleatorio 1: 8906
# Número aleatorio 2: 3168
# Número aleatorio 3: 362
# Número aleatorio 4: 1310
# Número aleatorio 5: 7161
# Número aleatorio 6: 2799
# Número aleatorio 7: 8344
# Número aleatorio 8: 6223
# Número aleatorio 9: 7257
# Número aleatorio 10: 6640
# Número aleatorio 11: 896
# Número aleatorio 12: 8028
# Número aleatorio 13: 4487
# Número aleatorio 14: 1331
# Número aleatorio 15: 7715
# Número aleatorio 16: 5212
# Número aleatorio 17: 1649
# Número aleatorio 18: 7192
# Número aleatorio 19: 7248
# Número aleatorio 20: 5335
# Número aleatorio 21: 4622
# Número aleatorio 22: 3628
# Número aleatorio 23: 1623
# Número aleatorio 24: 6341
# Número aleatorio 25: 2082
# Número aleatorio 26: 3347
# Número aleatorio 27: 2024
# Número aleatorio 28: 965
# Número aleatorio 29: 9312
# Número aleatorio 30: 7133
# Número aleatorio 31: 8796
# Número aleatorio 32: 3696
# Número aleatorio 33: 6604
# Número aleatorio 34: 6128
# Número aleatorio 35: 5523
# Número aleatorio 36: 5035
# ...

# %%
#metodo de medios cuadrados
# Semilla inicial
semilla = 5731
n = 4
iteraciones = 100
numeros_generados = []

for _ in range(iteraciones):
    # Elevar la semilla al cuadrado
    cuadrado = str(semilla ** 2).zfill(2 * n)

    # Extraer los primeros y últimos n/2 dígitos
    primera_parte = cuadrado[:n//2]  # Primeros n/2 dígitos
    segunda_parte = cuadrado[-(n//2):]  # Últimos n/2 dígitos
    semilla = int(primera_parte + segunda_parte)  # Concatenar para formar la nueva semilla

    numeros_generados.append(semilla)

# Imprimir los resultados
for indice, valor in enumerate(numeros_generados, 1):
    print(f"Número aleatorio {indice}: {valor}")
# Out:
# Número aleatorio 1: 3261
# Número aleatorio 2: 1021
# Número aleatorio 3: 141
# Número aleatorio 4: 81
# Número aleatorio 5: 61
# Número aleatorio 6: 21
# Número aleatorio 7: 41
# Número aleatorio 8: 81
# Número aleatorio 9: 61
# Número aleatorio 10: 21
# Número aleatorio 11: 41
# Número aleatorio 12: 81
# Número aleatorio 13: 61
# Número aleatorio 14: 21
# Número aleatorio 15: 41
# Número aleatorio 16: 81
# Número aleatorio 17: 61
# Número aleatorio 18: 21
# Número aleatorio 19: 41
# Número aleatorio 20: 81
# Número aleatorio 21: 61
# Número aleatorio 22: 21
# Número aleatorio 23: 41
# Número aleatorio 24: 81
# Número aleatorio 25: 61
# Número aleatorio 26: 21
# Número aleatorio 27: 41
# Número aleatorio 28: 81
# Número aleatorio 29: 61
# Número aleatorio 30: 21
# Número aleatorio 31: 41
# Número aleatorio 32: 81
# Número aleatorio 33: 61
# Número aleatorio 34: 21
# Número aleatorio 35: 41
# Número aleatorio 36: 81
# Número aleatorio 37: 61
# Número aleatorio 38: 21
# ...
